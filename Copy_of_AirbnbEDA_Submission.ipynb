# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involves a comprehensive analysis of an Airbnb dataset containing 48,895 observations and 16 columns. The primary goal is to extract meaningful insights from this data so that management and stakeholders can make informed decisions to improve and expand the business. By identifying key trends, guest preferences, and host performance indicators, we can create actionable recommendations that will ultimately enhance customer satisfaction and boost revenue.
#
# The dataset contains diverse information, such as:
#
# -Listing counts
#
# -Distribution across neighborhood groups
#
# -Pricing data
#
# -Reviews and ratings
#
# -Room type preferences
#
# From this data, we aim to uncover insights such as:
#
# -The most preferred room types by guests
#
# -Popular price ranges and budget trends
#
# -The most in-demand neighborhoods
#
# -Patterns in review activity and guest satisfaction
#
# These insights can support a more personalized guest experience. For example, we can create a recommendation and filtering system that shows guests listings within their budget and preferred location, while also ranking hosts based on how closely they match guest needs. This ensures guests find the right stay quickly, while hosts receive clear guidance on how to improve their listings for better visibility and higher bookings.
#
# Technical Approach
# To prepare the dataset for analysis, we will carry out extensive data wrangling using pandas, including handling missing values, formatting data types, and creating additional columns if needed. In some cases, separate DataFrames may be created for better organization and easier access.
#
# For numerical calculations — such as ranking hosts, calculating review statistics, and analyzing pricing patterns — we will use numpy, leveraging its efficiency in handling large datasets.
#
# Visualization is an essential part of this analysis, as it makes insights more understandable for decision-makers. We will use Matplotlib and Seaborn to create charts such as correlation heatmaps, scatterplots, and distribution plots. These visuals will allow stakeholders to quickly grasp patterns and relationships in the data without going through raw numbers.
#
# Business Impact
# The ability to pinpoint customer preferences and high-performing areas allows management to focus marketing and improvement efforts more effectively. For example, knowing the top neighborhoods and most successful price ranges can guide property acquisition, targeted advertising, and host training programs. Identifying underperforming areas and applying strategies from top locations can help distribute bookings more evenly and increase total market coverage.
#
# Learning Outcomes
# From a learning perspective, this project provides real-world exposure to the hospitality and short-term rental industry. It strengthens skills in problem identification, data cleaning, statistical analysis, and storytelling with data. It also encourages strategic thinking — not just reporting what the data says, but understanding why patterns exist and how they can be used to create business value. On the technical side, it enhances proficiency with Python’s data science ecosystem, especially in leveraging the most efficient methods within pandas, numpy, Matplotlib, and Seaborn to handle complex datasets.
#
# By the end of this analysis, we will not only have a clear picture of what drives customer satisfaction and booking trends, but also a set of actionable strategies for both guests and hosts that can lead to measurable business growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/saim5010/Exploratory-Data-Analysis---AirBnb-Bookings-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The goal of this project is to analyze the given dataset to uncover meaningful insights that can be used by stakeholders to make informed decisions for business improvement. By examining patterns, trends, and relationships within the data, we aim to highlight actionable areas that can enhance both guest and host experiences.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective is to identify opportunities for improvement and recognize patterns in customer preferences. These insights will help in refining pricing strategies, optimizing property offerings, and improving service quality — all with the ultimate aim of increasing customer satisfaction and driving business growth.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Check shape of the dataset
print("Shape of the dataset:", df.shape)

# Check column names
print("\nColumn Names:\n", df.columns.tolist())

# Display the first 5 rows
df.head()
# Out:
# Shape of the dataset: (48895, 16)
#
# Column Names:
#  ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 48895
# Number of Columns: 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# Here we can see the division of Categorical and Numerical values in our dataset:
#
# 3 columns have float64 data values (Numerical)
#
# 7 columns have int64 data type values (Numerical)
#
# 6 columns have object data type values (Categorical)

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows in the dataset: {duplicate_count}")
# Out:
# Number of duplicate rows in the dataset: 0

# %%
#Check duolicate value for other columns as well,like id and name
# Let us first check for 'id' column.
duplicated_id = df[df.duplicated(subset=['id'])]
display(duplicated_id)
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# No dulicated 'id's in our dataset.

# %%
#Let us check for 'name' column.
duplicated_name = df[df.duplicated(subset=['name'])]
display(duplicated_name)
# Out:
#              id                                               name    host_id  \
# 330       81739                  Loft w/ Terrace @ Box House Hotel     417504
# 339       84010                               Superior @ Box House     417504
# 580      219818                 ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿    1138692
# 661      250537                                The Lenox in Harlem    1313306
# 669      253471                   Loft Suite @ The Box House Hotel     417504
# ...         ...                                                ...        ...
# 48684  36382847                                       Comfort home  266211707
# 48735  36412461  Sunny, Cozy, Private Room In The Heart of Bush...  147515897
# 48759  36420404                                    Home Sweet Home  273656890
# 48791  36427922                                Home away from home  238163900
# 48826  36449743                                  Brooklyn's finest   66084717
#
# ...

# %% [markdown]
# Now as we can see we have 998 rows that are duplicates.Let us observe any one of the rows.

# %%
# We can check for any specific row having the name value included in the duplicated data.
# Let's check for where name is 'Superior @ Box House', which is in our duplicated data.
df.query('name == "Superior @ Box House"')
# Out:
#          id                  name  host_id            host_name  \
# 321   77765  Superior @ Box House   417504  The Box House Hotel
# 339   84010  Superior @ Box House   417504  The Box House Hotel
# 682  253846  Superior @ Box House   417504  The Box House Hotel
#
#     neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 321            Brooklyn    Greenpoint  40.73749  -73.95292  Private room
# 339            Brooklyn    Greenpoint  40.73813  -73.95394  Private room
# 682            Brooklyn    Greenpoint  40.73731  -73.95450  Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 321    179               3                 36  2019-07-01               0.36
# 339    179               3                 13  2019-06-27               0.14
# 682    179               3                  4  2015-12-04               0.05
#
#      calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# Here we can observe that almost all the values are same except for the id, latitude, longitude, number_of_reviews, reviews_per_month, availability_365.

# %%
# To tackle this issue we will create a new data frame in which we will include
# only those columns which are really important for us.
df = df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365']].copy()

# %%
#Let's check for the duplicated values of any other row.
df.query('name == "Loft w/ Terrace @ Box House Hotel"')
# Out:
#          id                               name  host_id            host_name  \
# 328   80700  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
# 330   81739  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
# 680  253839  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
#
#     neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 328            Brooklyn    Greenpoint  40.73738  -73.95482  Private room
# 330            Brooklyn    Greenpoint  40.73842  -73.95312  Private room
# 680            Brooklyn    Greenpoint  40.73783  -73.95259  Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 328    349               3                  7  2019-05-24               0.07
# 330    249               3                  2  2011-05-12               0.02
# 680    249               3                  3  2015-11-03               0.03
#
# ...

# %% [markdown]
# As we can see here each and every value is almost the same, except for the prices.

# %%
# In this case we will seek out the duplicated values for those columns which
# are concerning and may effect the data if duplicated.

# Checking for the values where - 'name', 'host_name','neighbourhood_group', 'neighbourhood', 'room_type' are duplicated
df.loc[df.duplicated(subset= ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'])]
# Out:
#              id                                               name    host_id  \
# 330       81739                  Loft w/ Terrace @ Box House Hotel     417504
# 339       84010                               Superior @ Box House     417504
# 580      219818                 ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿    1138692
# 669      253471                   Loft Suite @ The Box House Hotel     417504
# 670      253475                   Loft Suite @ The Box House Hotel     417504
# ...         ...                                                ...        ...
# 47876  35966653             Bright, contemporary and best location   24232061
# 48026  36039574                 ★Premier Queen Room with Balcony ★  270874051
# 48207  36139806  30 mins to Times Square!! 15 mins LGA, 25mins ...  260209224
# 48662  36372006  Very Clean Private Room Near Buses & Restauran...  118405437
# 48684  36382847                                       Comfort home  266211707
#
# ...

# %%
# Let's check for any specific value.
df.query('name == "✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿"')
# Out:
#          id                                name  host_id     host_name  \
# 579  219793  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
# 580  219818  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
#
#     neighbourhood_group    neighbourhood  latitude  longitude  \
# 579           Manhattan  Lower East Side  40.71813  -73.98416
# 580           Manhattan  Lower East Side  40.71892  -73.98401
#
#            room_type  price  minimum_nights  number_of_reviews last_review  \
# 579  Entire home/apt    199               1                 29  2015-06-03
# 580  Entire home/apt    199               1                 14  2015-07-20
#
#      reviews_per_month  calculated_host_listings_count  availability_365
# 579               0.31                               2               162
# 580               0.15                               2               158

# %% [markdown]
# In this now we can see that all the values are same except for last_review and reviews_per_month, which are not so important regarding duplicacy.
#
# Now to drop the duplicated values we will sort out dataframe on the basis of latest entries, for which we need to have a timestamp in our dataset, in our dataset we can use the 'last_review' column as the timestamp for our dataset.

# %%
#Converting the 'last_review' column in a datetime format.
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
# Now let us sort the data by the last_review column
df = df.sort_values(by='last_review', ascending=False).reset_index(drop=True)

# %% [markdown]
# As we can see there are few NA values in our dataframe in the date column let's fill these values with the latest dates we are having in our dataframe.

# %%
# Replacing NA Values
df['last_review'].replace(np.nan,df['last_review'].max(), inplace=True)

# Let's sort the values again
df = df.sort_values(by='last_review', ascending=False).reset_index(drop=True)
# Out:
# /tmp/ipython-input-433497313.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['last_review'].replace(np.nan,df['last_review'].max(), inplace=True)

# %%
# Dropping duplicated values
df = df.drop_duplicates(subset=['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'], keep='first').reset_index(drop=True)

# Now the duplicated columns have been dropped, let's check the current shape of our data frame.
df.shape

# Let's check if there are any duplicated values now
df[df.duplicated(subset=['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'])] # No values

df.query('name == "✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿"')
# Out:
#            id                                name  host_id     host_name  \
# 48036  219818  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
#
#       neighbourhood_group    neighbourhood  latitude  longitude  \
# 48036           Manhattan  Lower East Side  40.71892  -73.98401
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48036  Entire home/apt    199               1                 14  2015-07-20
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 48036               0.15                               2               158

# %% [markdown]
# We have successfully dropped the duplicated values and now we only have latest data values

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
print(missing_values)
# Out:
# name                   16
# host_name              21
# reviews_per_month    9989
# dtype: int64

# %%
# Visualizing the missing values
missing_values.plot(kind='barh', figsize=(10,6), color='orange')
plt.title("Missing Values Count per Column")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# To check the outliers we need to check the columns which are having numerical data.
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.866200e+04  4.866200e+04  48662.000000  48662.000000  48662.000000
# mean   1.900484e+07  6.746247e+07     40.728926    -73.952196    152.658173
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.462062e+06  7.802407e+06     40.690000    -73.983068     69.000000
# 50%    1.965763e+07  3.070801e+07     40.722985    -73.955660    105.000000
# 75%    2.913386e+07  1.074344e+08     40.763130    -73.936270    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098022e+07  7.851441e+07      0.054569      0.046098    240.418499
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48662.000000       48662.000000                          48662
# mean         7.002219          23.337738  2018-11-30 01:10:55.903990784
# ...

# %% [markdown]
# If we look into this data we can see that the price and the minimum_nights columns are the most concerning ones, in these 2 columns we need to find the outliers and drop them.

# %%
#As we see above the column_name 'calculated_host_listings_count' is quiet long
# Let's change it to 'listings'
df.rename(columns={
    "calculated_host_listings_count": 'listings'
}, inplace=True)

# Lets check the price columns once
print("Price description before handling outliers:")
print(df['price'].describe())

# As we can see the min price is 0 which is not likely to happen.
# According to the current website the price range starts from $25.
# In this case we will check for the prices which are below $25 and we will
# replace their values with 25 so that we can handle the outliers in price column.

# Replacing values below 25 with 25 using .loc
df.loc[df['price'] < 25, 'price'] = 25
print("\nPrice description after handling outliers:")
print(df['price'].describe())
# Out:
# Price description before handling outliers:
# count    48662.000000
# mean       152.658173
# std        240.418499
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64
#
# Price description after handling outliers:
# count    48662.000000
# mean       152.679791
# std        240.406397
# min         25.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# As the few price values were less than $25, which is not likely to happen, we have converted those values into 25, so that we may handle the outliers more efficiently, as there was other crucial info present in those rows.

# %%
# Now let check the minimum_nights column.
print("Minimum nights description before handling outliers:")
print(df['minimum_nights'].describe())

# As the minimum value in this column is 1, we can work on only the upper limit.
# In this case if any value is more than 365 days, we will mark it as 365.

# Replacing values above 365 with 365 using .loc
df.loc[df['minimum_nights'] > 365, 'minimum_nights'] = 365
print("\nMinimum nights description after handling outliers:")
print(df['minimum_nights'].describe())
# Out:
# Minimum nights description before handling outliers:
# count    48662.000000
# mean         7.002219
# std         20.535357
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64
#
# Minimum nights description after handling outliers:
# count    48662.000000
# mean         6.914821
# std         17.543710
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        365.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# Now we have modified the outliers, we can move ahead with our dataset ready to be wrangled for deriving insights.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Airbnb NYC 2019 dataset contains 48,895 rows and 16 columns, providing detailed information about Airbnb listings in New York City.
#
# **Data Types**
#
# The dataset includes both categorical (e.g., neighbourhood_group, room_type) and numerical columns (e.g., price, availability_365, number_of_reviews).
#
# **Missing Values**
#
# Around 10,000 entries are missing in last_review and reviews_per_month, likely because those listings had no reviews.
#
# Name and host_name have very few missing values, which may not impact analysis significantly.
#
# **Duplicates**
#
# The dataset has 0 exact duplicate rows, which is ideal for analysis.
#
# However in the name column there were 989 rows that were duplicates.
#
# **Geographic & Business Info**
#
# Listings are spread across 5 boroughs: Manhattan, Brooklyn, Queens, Bronx, and Staten Island.
#
# Room types include Entire home/apt, Private room, and Shared room.
#
# Prices and minimum nights vary widely and need further exploration for outliers.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Column Names in the Dataset:\n")
print(df.columns.tolist())
# Out:
# Column Names in the Dataset:
#
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'listings', 'availability_365']

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.866200e+04  4.866200e+04  48662.000000  48662.000000  48662.000000
# mean   1.900484e+07  6.746247e+07     40.728926    -73.952196    152.679791
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     25.000000
# 25%    9.462062e+06  7.802407e+06     40.690000    -73.983068     69.000000
# 50%    1.965763e+07  3.070801e+07     40.722985    -73.955660    105.000000
# 75%    2.913386e+07  1.074344e+08     40.763130    -73.936270    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
# std    1.098022e+07  7.851441e+07      0.054569      0.046098    240.406397
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    48662.000000       48662.000000                          48662
# mean         6.914821          23.337738  2018-11-30 01:10:55.903990784
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Variables Description
#
# This dataset has information about Airbnb listings in New York City. Each row is one listing. Some important variables are:
#
# id: A unique number given to each listing.
#
# name: The name or title of the listing.
#
# host_id: A unique number for each host.
#
# host_name: The name of the person who listed the property.
#
# neighbourhood_group: The borough where the listing is located (like Manhattan or Brooklyn).
#
# neighbourhood: The specific area or neighborhood inside the borough.
#
# latitude & longitude: The location of the listing on the map.
#
# room_type: The kind of room (Entire home, Private room, or Shared room).
#
# price: The price per night in dollars.
#
# minimum_nights: Minimum stay required.
#
# number_of_reviews: Total number of reviews received.
#
# last_review: The date when the last review was posted.
#
# reviews_per_month: Average number of reviews the listing gets in a month.
#
# calculated_host_listings_count: How many listings the host has.
#
# availability_365: How many days in a year the listing is available.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = df.nunique()
print("Unique values per column:\n")
print(unique_values)
# Out:
# Unique values per column:
#
# id                     48662
# name                   47905
# host_id                37447
# host_name              11452
# neighbourhood_group        5
# neighbourhood            221
# latitude               19022
# longitude              14678
# room_type                  3
# price                    659
# minimum_nights           101
# number_of_reviews        394
# last_review             1762
# reviews_per_month        936
# listings                  47
# availability_365         366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Let create a new column with the price range distribution.
# We will use it while working with the price column.
# Ensure price column is numeric
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Define price range bins
price_bins = np.linspace(0, 10000, 101).astype(int)

# Function to assign price to a range
def get_price_range(amount):
    for i in range(len(price_bins) - 1):
        if price_bins[i] <= amount < price_bins[i + 1]:
            return f"{price_bins[i]} - {price_bins[i + 1]}"
    return f"{price_bins[-1]}+"

# Apply the function safely
df['price_range'] = df['price'].apply(lambda x: get_price_range(x) if pd.notnull(x) else 'Unknown')

# View a few rows
df[['price', 'price_range']].head()
# Out:
#    price price_range
# 0     30     0 - 100
# 1     56     0 - 100
# 2    300   300 - 400
# 3     35     0 - 100
# 4    150   100 - 200

# %% [markdown]
# Why Creating a Price Range Column is Beneficial
# Creating a price range column in your dataset adds significant value in several ways:
#
# 1. Simplifies Data Understanding
# Grouping prices into defined ranges helps to quickly grasp the overall distribution. Instead of analyzing individual price points, you get a broader overview that's easier to interpret.
#
# 2. Enhances Visualizations
# Charts and graphs based on price ranges (like bar plots or histograms) are often more meaningful and visually effective than those using raw prices, especially when prices vary widely.
#
# 3. Enables Better Segmentation
# Dividing prices into categories allows you to analyze different customer or product segments. This makes it easier to compare patterns or trends within each price group.
#
# 4. Supports Smarter Decision-Making
# Whether it's setting pricing strategies or recommending products, price ranges help tailor decisions to customer budgets and needs more accurately.
#
# 5. Communicates Insights Clearly
# A price range column makes it easier to convey customer affordability and preferences to stakeholders. It also helps identify where most of your customers fall in terms of purchasing power.

# %%
#Let us sort our dataset according to the price.
df.sort_values(by='price', ascending=False, inplace=True)

# Let's take a look at our price sorted dataset once.
df.head()
# Out:
#              id                                               name   host_id  \
# 42906  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 1809   22436899                                1-BR Lincoln Center  72390391
# 46635   7003697                Furnished room in Astoria apartment  20582832
# 46974   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
# 9953   31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 42906      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 1809     Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 46635  Kathrine              Queens          Astoria  40.76810  -73.91651
# 46974       Amy           Manhattan  Lower East Side  40.71355  -73.98507
# 9953       Matt           Manhattan  Lower East Side  40.71980  -73.98566
#
# ...

# %%
# Let us check our columns and filter those columns that will work as our features.
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'listings', 'availability_365', 'price_range'],
#       dtype='object')

# %% [markdown]
# We can consider these columns to be our attributes so that we can work with these:-
#
# id
#
# host_id
#
# host_name
#
# neighbourhood_group
#
# neighbourhood
#
# room_type
#
# price
#
# price_range
#
# minimum_nights
#
# number_of_reviews
#
# reviews_per_month
#
# listings
#
# availability_365

# %%
# Let filter the dataframe with only the required columns.
feature_df =df[['id', 'name', 'host_id','host_name', 'neighbourhood_group',
       'neighbourhood', 'room_type', 'price', 'minimum_nights',
       'number_of_reviews', 'reviews_per_month', 'listings',
       'availability_365', 'price_range']]

feature_df = feature_df.reset_index(drop=True)
feature_df.head()
# Out:
#          id                                               name   host_id  \
# 0  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 1  22436899                                1-BR Lincoln Center  72390391
# 2   7003697                Furnished room in Astoria apartment  20582832
# 3   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
# 4  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
#
#   host_name neighbourhood_group    neighbourhood        room_type  price  \
# 0      Erin            Brooklyn       Greenpoint  Entire home/apt  10000
# 1    Jelena           Manhattan  Upper West Side  Entire home/apt  10000
# 2  Kathrine              Queens          Astoria     Private room  10000
# 3       Amy           Manhattan  Lower East Side     Private room   9999
# 4      Matt           Manhattan  Lower East Side  Entire home/apt   9999
#
#    minimum_nights  number_of_reviews  reviews_per_month  listings  \
# ...

# %% [markdown]
# As we can see we are having few groups in our datasets, let us check what all insights we can derive from them, by seeking information according to the groups.

# %%
# Let's check the top performing Host as per the total listing count
host_groups = feature_df.groupby('name')
hosts = []
no_of_listings = []
host_prices = []
for host, data in host_groups:
  hosts.append(host)
  no_of_listings.append(data['listings'].sum())
  host_prices.append(data['price'].mean())

host_df = pd.DataFrame({
    'Host Name': hosts,
    'Total Listings': no_of_listings,
    'Price': host_prices
})
host_df = host_df.sort_values(by='Total Listings', ascending=False).reset_index(drop=True)
host_df = host_df.drop_duplicates(subset='Total Listings').reset_index(drop=True)
top_10_hosts = host_df.head(10)

host_df['Revenue'] = (host_df['Total Listings'])*(host_df['Price'])
top_host_revenue = host_df.sort_values(by='Revenue', ascending=False).reset_index(drop=True)
top_host_revenue.head(10)
# Out:
#                                            Host Name  Total Listings  \
# 0             Pleasant 1BR in Midtown East by Sonder             654
# 1        Sonder | Stock Exchange | Cozy 1BR + Lounge             327
# 2       West 55th street, Lux 1bd Serviced Apartment             261
# 3  Gorgeous + Bright Midtown East 1BR, Doorman, G...             232
# 4  *NO GUEST SERVICE FEE* Beekman Tower One Bedro...              49
# 5     West 15th Street Cozy Chelsea 1bd Serviced Apt             174
# 6  Stunning 1 Bedroom Apt. in  NYC, w/d in the unit!             121
# 7                2BR WITH PRIVATE PATIO EAST VILLAGE             114
# 8          DOORMAN/ GYM/ MODERN 2 BR ON EAST 52ND ST              65
# 9       Prime Location One Bed Doorman Gym Deck!5223              96
#
#         Price   Revenue
# 0  197.000000  128838.0
# 1  229.000000   74883.0
# 2  251.666667   65685.0
# 3  241.000000   55912.0
# 4  714.000000   34986.0
# 5  200.000000   34800.0
# 6  239.000000   28919.0
# ...

# %%
# First let's check how many neighbourhood_groups are there.
feature_df['neighbourhood_group'].unique() # There are 5 different groups.

# ['Brooklyn', 'Queens', 'Manhattan', 'Staten Island', 'Bronx']
#  let's group our dataset according to the neighbourhood groups.

n_groups = feature_df.groupby('neighbourhood_group')

# Let's check which group is most prefered as per the listings, and no. of reviews.
groups = [] # To save the groups
listings = []
reviews = []
max_price = []
min_price = []
for group, data in n_groups:
  groups.append(group)
  listings.append(data['listings'].sum())
  reviews.append(data['number_of_reviews'].sum())
  max_price.append(data['price'].max())
  min_price.append(data['price'].min())

group_feat_df = pd.DataFrame({
    'Group': groups,
    'Listing Count': listings,
    'No._of_reviews': reviews,
    'Min Price': min_price,
    'Max Price': max_price
})

group_feat_df
# Here we can see that Manhattan group is the most prefered group as per the listings.
# However the most reviews are given to the Brooklyn group.

# Now let's divide our dataset as per the room types, and create their groups.
# First let's check how room_types are there.

feature_df['room_type'].unique() # There are 3 room types.

# ['Entire home/apt', 'Private room', 'Shared room']
#  let's group our dataset according to the room types.

room_groups = feature_df.groupby('room_type')
rooms = []
room_listings = []
room_reviews = []
max_room_price = []
min_room_price = []
for room_type, room_data in room_groups:
    rooms.append(room_type)
    room_listings.append(room_data['listings'].sum())
    max_room_price.append(room_data['price'].max())
    min_room_price.append(room_data['price'].min())

room_feat_df = pd.DataFrame({
    'Group': rooms,
    'Listing Count': room_listings,
    'Min Price': min_room_price,
    'Max Price': max_room_price
})

room_feat_df
# Here we can see the most prefered room type is the Entire home/apt.
# The most reviews are also given to the Entire home/apt.
# Shared rooms are the least prefered.
# Out:
#              Group  Listing Count  Min Price  Max Price
# 0  Entire home/apt         263986         25      10000
# 1     Private room          70813         25      10000
# 2      Shared room           5323         25       1800

# %%
# Now let us check how many different neighbourhoods are there in total.
feature_df['neighbourhood'].count() # There are 48655 neighbourhoods

# Now let us check what are the top 10 most prefered neighbourhoods.
# Also, let's check their average pricing and average price range.
area_groups = feature_df.groupby('neighbourhood')
areas = []
listing_count = []
avg_price = []
for area, n_data in area_groups:
  areas.append(area)
  listing_count.append(n_data['listings'].sum())
  avg_price.append(round(n_data['price'].mean(), 2))

area_feat_df = pd.DataFrame({
    'Area': areas,
    'Listing Count': listing_count,
    'Average Price': avg_price,
})

area_feat_df = area_feat_df.sort_values(by='Listing Count', ascending=False).reset_index(drop=True)
area_feat_df.head(10)
# Out:
#                  Area  Listing Count  Average Price
# 0  Financial District          84942         226.03
# 1      Hell's Kitchen          24754         205.33
# 2         Murray Hill          24726         221.18
# 3             Midtown          24647         282.66
# 4             Chelsea          17483         248.36
# 5    Theater District          16151         242.67
# 6     Upper East Side          14909         189.10
# 7     Upper West Side          13201         211.25
# 8  Bedford-Stuyvesant           9605         107.77
# 9             Tribeca           7519         492.23

# %%
# Let us now work with relationships.
# Relationship: Price vs. Room Type
# Checking the distribution of prices for different room types.
# "room_groups" is our grouped dataframe we will be using this.

avg_room_price = []
for room, data in room_groups:
  avg_room_price.append(data['price'].mean())

room_vs_price = pd.DataFrame({
    'Room Type': rooms,
    'Avg_Price': avg_room_price
})

room_vs_price

# As we can see here the Entire home/apt is having the highest pricing.
# Out:
#          Room Type   Avg_Price
# 0  Entire home/apt  211.692566
# 1     Private room   89.631218
# 2      Shared room   70.536395

# %%
# Relationship: Reviews per Month vs. Room Type
# Comparing the distribution of reviews per month for different room types.

total_reviews = []
for room, data in room_groups:
  total_reviews.append(data['reviews_per_month'].sum())

room_vs_reviews = pd.DataFrame({
    'Room Type': rooms,
    'Reviews': total_reviews
})

room_vs_reviews
# As we can see here the Entire home/apt is having the highest no. of reviews per month.
# Out:
#          Room Type   Reviews
# 0  Entire home/apt  26525.13
# 1     Private room  25415.29
# 2      Shared room   1232.65

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We analyzed a well-distributed Airbnb dataset, with a focus on location-based trends, which are crucial for this domain.
#
#  Key Manipulations:
#
# Created a price range column to group listings by budget.
#
# Sorted data by price to highlight high-end listings.
#
# Filtered relevant columns for cleaner analysis.
#
# Grouped data by:
#
# Neighbourhood Group
#
# Room Type
#
# Neighbourhood Area
#
#  Relationships Explored:
#
# Price vs. Room Type - to identify pricing patterns.
#
# Reviews per Month vs. Room Type - to assess engagement.
#
# Price vs. Neighbourhood - to spot high and low-cost areas.
#
# Purpose:
#
# These steps helped generate insights to guide business decisions, improve host strategies, and enhance the customer experience.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Chart - 1: Most preferred neighbourhood group (Bar Chart)

plt.figure(figsize=(10, 5))

colors = ['red', 'blue', 'green', 'orange', 'purple']  # Distinct colors for each bar

sns.barplot(
    x="Group",
    y="Listing Count",
    data=group_feat_df,
    hue="Group",
    palette=colors,
    legend=False
)

plt.xlabel("Neighbourhood Groups")
plt.ylabel("Listing Counts")
plt.title("Most Preferred Neighbourhood Group")

# Annotate bars with exact values
for x, y in zip(range(len(groups)), listings):
    plt.text(x, y, f'{y}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used a bar chart because our goal was to compare the listing counts across different neighbourhood groups. To visually identify which group has the highest number of listings and to compare them side by side, a bar chart is the most effective and easy-to-read option.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, it's clear that:
#
# Manhattan is the most preferred neighbourhood group, with the highest number of listings.
#
# Brooklyn is the second most preferred group.
#
# Other neighbourhoods have significantly fewer listings, showing a clear difference in demand across areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are valuable for business decisions:
#
# Knowing that Manhattan is in highest demand helps us focus our listings, services, and marketing efforts in that area to meet customer expectations and boost bookings.
#
# The lower demand in other neighbourhoods could be a concern, but also an opportunity. If we analyze what makes Manhattan popular—like better location, amenities, or accessibility—we can work on improving the other areas too.
#
# This approach not only supports growth where demand is high but also helps reduce the gap in less popular areas.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Get the top 10 most frequent price ranges
prefered_range = df['price_range'].value_counts().head(10)

# Sort the index for better line connection
prefered_range_sorted = prefered_range.sort_index()

# Plotting
plt.figure(figsize=(10, 5))
plt.scatter(prefered_range.index, prefered_range, color='blue', marker='o')  # Scatter points
plt.plot(prefered_range_sorted.index, prefered_range_sorted, color='black', linewidth=2, label='Trend Line')  # Line connecting dots

# Add data labels
for x, y in zip(prefered_range_sorted.index, prefered_range_sorted):
    plt.text(x, y, f'{y}', ha='center', va='bottom')

# Chart labels and title
plt.title("Top 10 Preferred Price Ranges")
plt.xlabel("Price Range")
plt.ylabel("Number of Listings")
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart because it helps us clearly see which price ranges are more popular among customers. It shows how the number of listings changes with different price ranges. As the price increases, we can see that the preference drops — which is exactly what we wanted to observe.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart, it's clear that most customers prefer listings in the ₹0-100 price range (excluding actual zero-priced ones we removed earlier). This tells us that people mostly look for budget-friendly stays. It also helps us understand how much people are usually willing to spend, which is useful when setting prices or making recommendations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights will support a positive business impact.
# By understanding that customers prefer listings within specific budget ranges, we can:
#
# Personalize recommendations
#
# Help hosts price competitively
#
# Improve customer satisfaction by showing relevant options quickly
#
# There's no direct sign of negative growth, but the lower demand for higher price ranges suggests a need to re-evaluate those listings—possibly by improving their value proposition, amenities, or marketing to a different customer segment.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Let's visualize the most prefered room type using a pie chart

room_feat_df # Our grouped df created earlier

# Plotting the data into a pie chart
plt.pie(room_feat_df['Listing Count'], labels=room_feat_df['Group'], autopct="%1i%%", explode=(0.1, 0, 0.1), shadow=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since we had just three types of rooms, a pie chart was a good choice. It makes it easy to see how the listings are divided among the room types. Also, the percentage view helps us quickly understand how popular each room type is compared to the others.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly shows that "Entire Home/Apt" is the most preferred room type. This suggests that most people value privacy and want a place to themselves. On the other hand, shared rooms are the least popular, likely preferred by students or those looking for cheaper stays. These insights can help us target the right audience better.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it can help a lot. If we know what people prefer, we can focus our marketing and promotions accordingly — which saves costs and improves results.
# Also, by understanding who prefers less popular room types, we can still target them with specific offers. This helps in increasing reach even in low-demand areas.
# There's no real negative side here, but we should explore why some room types are less preferred and find ways to make them more attractive.

# %% [markdown]
# #### Chart - 4

# %%
# Chart-4 visualization code
# Let us now visualize the average price division with room types.

data = {
    'Room Type': room_vs_price['Room Type'],
    'Avg_Price': room_vs_price['Avg_Price'],
    'Listings': ((room_feat_df['Listing Count']/room_feat_df['Listing Count'].sum())*100)
}

# Creating a DataFrame
df = pd.DataFrame(data)

df_melted = pd.melt(df, id_vars='Room Type', var_name='Attribute', value_name='Value')
# Creating a strip plot
sns.barplot(x='Room Type', y='Value', data=df_melted, hue="Attribute", palette=['blue', 'grey'], legend=True)

# Applying annotations on the values
for p in plt.gca().patches:
    plt.gca().annotate('{:.1f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                       textcoords='offset points')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since we only had 3 room types, a bar chart was a good choice to clearly show both the average price and how the listings are spread out across them. It gives a quick visual of how prices vary with room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Entire Home/Apt has the highest average price, and also a large share of listings. This means there's a strong connection between pricing and the popularity of this room type. It's helpful for deciding on pricing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, definitely. Knowing how much customers are willing to pay for each room type helps us set smarter prices. This can boost bookings and customer satisfaction.
# There aren't any major negatives, but we should still keep an eye on less popular room types and explore why they aren't performing as well.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Let's visualize the relationship between listing price and the number of reviews received.
# As we are having huge number of rows for this we will be taking only top 10 price ranges.
# For the listing prices we will take price_range

sorted_range = feature_df.sort_values(by='price_range', ascending=False)
sorted_range = sorted_range.groupby('price_range')
range_group = []
review_count = []
for range, data in sorted_range:
  range_group.append(range)
  review_count.append(data['number_of_reviews'].sum())

range_df = pd.DataFrame({
    'Range': range_group,
    'Review Count': review_count
})
plt.figure(figsize=(15, 5))
sns.scatterplot(x='Range', y='Review Count', data=range_df.head(10), color='blue', legend=False, marker='o')
plt.plot(range_df['Range'].head(10), range_df['Review Count'].head(10), color='grey', linestyle='--', linewidth=2, label='Line Connecting Dots')
plt.title("Price vs Reviews of top 10 most prefered price range")
for x, y in zip(range_df['Range'].head(10), range_df['Review Count'].head(10)):
  plt.text(x, y, f'{y}', ha='center', va='bottom')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since there's a huge difference in the number of reviews across different price ranges, using a plot chart makes it easier to clearly see those differences. It helps show not just the values, but how much they vary from one price point to another — which would be harder to spot with a basic bar or pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the number of reviews drops as the price increases. This suggests most customers are looking for budget-friendly options, especially in the $ 0- 200 range.
# But interestingly, there are still a few listings in the higher price brackets that get reviews — showing that there is some demand even in those segments, possibly with more competition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, definitely. Knowing that most customers prefer lower-priced listings helps us plan better pricing strategies. We can focus on offering more listings in the affordable range to attract a bigger audience.
# At the same time, since there's some activity in the higher price range too, we shouldn't ignore that segment — maybe we can fine-tune premium offerings to stand out.
# There doesn't seem to be any negative sign here, unless we completely overlook one of the segments. The key is to balance both ends smartly.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Let us also check for the least 10 prefered price ranges
plt.figure(figsize=(15, 5))
sns.scatterplot(x='Range', y='Review Count', data=range_df.tail(10), color='blue', legend=False, marker='o')
plt.plot(range_df['Range'].tail(10), range_df['Review Count'].tail(10), color='grey', linestyle='--', linewidth=2, label='Line Connecting Dots')
plt.title("Price vs Reviews of bottom least 10 prefered price range")
for x, y in zip(range_df['Range'].tail(10), range_df['Review Count'].tail(10)):
  plt.text(x, y, f'{y}', ha='center', va='bottom')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps identify the price ranges that attract the least customer engagement, shown through lower review counts. Using a scatterplot with a line, we can easily spot trends and compare the least performing price segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the bottom 10 price ranges in terms of reviews, suggesting that these ranges are less attractive to users.
#
# These low-engagement price points might be overpriced, offer poor value, or simply be less competitive compared to other listings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding which price ranges receive minimal engagement helps avoid those pricing strategies. Businesses can adjust their pricing to fall into more favorable ranges, boosting visibility and bookings. This prevents stagnation and encourages competitive, customer-aligned pricing.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Let us know the price range having the highest listings so as to get more specific idea on price preference.
sorted_range # Sorted Price Range grouped
range_group # List of all the price range groups
range_listing_count = []

for range, data in sorted_range:
  range_listing_count.append(data['listings'].sum())


range_list_df = pd.DataFrame({
    'Range': range_group,
    'Listing Count': range_listing_count
})

range_list_df = range_list_df.sort_values(by='Listing Count', ascending=False).reset_index(drop=True)

# We will be taking on the top 5 prefered ranges.
plt.pie(range_list_df['Listing Count'].head(), labels=range_list_df['Range'].head(), autopct="%1i%%", explode=(0.1, 0.1, 0.1, 0, 0), shadow=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pie chart because it gives a quick and clear picture of how listings are spread across different price ranges. It’s simple to understand and makes it easy to compare which price segments are more popular.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most listings fall under $300. Specifically:
#
# 200-300 $ has the highest number of listings (33%)
#
# 100-200 $ is next (28%)
#
# 0-100 $ comes third (22%)
#
# So, about 8 out of 10 listings are in the budget category, which tells us people prefer affordable options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely. Knowing that budget stays are in demand helps businesses focus on creating more affordable options, promoting the right listings, or suggesting price adjustments to hosts.
#
# There's no clear sign of negative impact here, but listings priced too high might not perform well unless they offer something extra that justifies the cost.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# As now we are having the price ranges with the most listings let us check the neighbourhoods with the most listings.
areas = []
area_listing = []
area_group = feature_df.groupby('neighbourhood')
for area, data in area_group:
    areas.append(area)
    area_listing.append(data['listings'].sum())

area_data_df = pd.DataFrame({
    "Area": areas,
    "Values": area_listing
})
area_data_df = area_data_df.sort_values(by='Values', ascending=False).reset_index(drop=True)
area_data_df
plt.figure(figsize=(17,5))
# plt.plot(groups,listings, color='black', marker = "o", markerfacecolor = 'blue', markeredgecolor='blue',linestyle='-')
colors = ['red', 'blue', 'green', 'orange', 'purple']
sns.barplot(x="Area", y='Values', data=area_data_df.head(10), hue="Area", palette=colors, legend=False)
plt.title('Top 10 prefered neighbourhood areas')
plt.xlabel('Area')
plt.ylabel('Listing Counts')
for x, y in zip(area_data_df['Area'].head(10), area_data_df['Values'].head(10)):
    plt.text(x, y, f'{y}', ha='center', va='bottom')
# Out:
# /tmp/ipython-input-249915957.py:19: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="Area", y='Values', data=area_data_df.head(10), hue="Area", palette=colors, legend=False)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart works well here because it clearly shows how listing counts vary across neighbourhoods. It's easy to compare areas side by side and spot which ones have the highest number of listings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the Financial District stands out with the highest number of listings — far ahead of the other neighbourhoods. This indicates it's a highly preferred location for both hosts and guests, possibly due to its centrality, convenience, or demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, absolutely. This kind of insight helps us focus on high-potential areas like the Financial District — we can explore adding more listings, offering targeted promotions, or improving services in that zone. There's no sign of negative growth here, but neighbourhoods with low listings could be further analyzed to understand if there's untapped demand or any barriers for hosts.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Reviews vs Review per month
sns.scatterplot(x='number_of_reviews', y='reviews_per_month', data=feature_df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='reviews_per_month'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal here because it shows how two continuous variables — total number of reviews and reviews per month — relate to each other. It also allows us to spot outliers and identify general patterns in user engagement over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot reveals a fairly clear linear trend: listings with higher total reviews tend to also receive more reviews per month. This suggests that these listings consistently attract guest interest and possibly offer a satisfying experience. There's also a visible outlier, which could indicate an unusually high-performing listing worth analyzing separately.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, definitely. These insights can help us identify high-performing listings and understand what makes them successful. We can then provide tailored recommendations to other hosts — such as pricing strategies, listing improvements, or guest engagement tactics — to help boost their visibility and customer satisfaction. This opens up opportunities for premium consulting services, benefiting both the platform and its hosts. There’s no clear indication of negative growth, but outliers could also signal abnormal activity worth investigating further.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart 10 - Distribution of Room Types Across Top 5 Neighbourhoods

# Step 1: Get top 5 neighbourhoods with most listings
top5_neighbourhoods = feature_df['neighbourhood'].value_counts().head(5).index

# Step 2: Filter the dataset for only these top 5 neighbourhoods
top5_data = feature_df[feature_df['neighbourhood'].isin(top5_neighbourhoods)]

# Step 3: Plot room type distribution for these neighbourhoods
plt.figure(figsize=(10,6))
sns.countplot(data=top5_data, x='neighbourhood', hue='room_type', palette='Set2')
plt.title('Distribution of Room Types Across Top 5 Neighbourhoods')
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.legend(title='Room Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to analyze the distribution of different room types across the top 5 most popular neighbourhoods by listing count. Understanding this distribution helps identify what types of accommodations dominate in key local markets and which neighbourhoods cater more to certain customer preferences (e.g., solo travelers vs. families).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Private rooms dominate in most top neighbourhoods, especially in Bedford-Stuyvesant, Harlem, and Bushwick.
#
# Entire home/apt listings are more prominent in Williamsburg and Upper West Side.
#
# Shared rooms are the least common room type across all top neighbourhoods.
#
# The listing pattern suggests that some neighbourhoods focus on affordable shared living while others offer premium private or entire home options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Hosts can tailor their listings based on what works best in each neighbourhood.
#
# For example, offering more private rooms in Harlem or Bedford-Stuyvesant could align with demand.
#
# Meanwhile, in Williamsburg, investing in entire apartments might yield better returns.
#
# Airbnb can optimize its marketing strategy by promoting the right room types in the right neighbourhoods.
#
# Possible Negative Insight:
#
# An oversaturation of private rooms in certain areas (e.g., Bushwick) could lead to price competition, reducing host earnings unless value-added services are introduced.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Group by price and sum the number of reviews
sns.scatterplot(x='price', y='number_of_reviews', data=feature_df)
# Out:
# <Axes: xlabel='price', ylabel='number_of_reviews'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot is ideal for showing how two continuous variables—price and total number of reviews—relate to each other. It gives a clear sense of the distribution, density, and potential outliers across the price spectrum.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of listings with high review counts fall within the low to mid price range (under $300).
#
# There are a few clear outliers with extremely high review totals, indicating very popular budget listings.
#
# As the price increases, the number of reviews tends to decrease drastically, suggesting that higher-priced listings get less traction or are more niche.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can be quite impactful. They highlight that:
#
# Listings priced under $300 are more attractive to customers and receive higher engagement.
#
# This can guide hosts to optimize pricing within this sweet spot to boost visibility and bookings.
#
# A potential downside is that high-priced listings may underperform if not paired with premium services or standout offerings. Businesses can focus marketing efforts on value-added features or adjust pricing strategies accordingly.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Group by host_name and calculate the average number of reviews
avg_reviews_host = feature_df.groupby('host_name')['number_of_reviews'].mean().sort_values(ascending=False).head(20)

# Plotting
plt.figure(figsize=(16, 6))
sns.barplot(x=avg_reviews_host.index, y=avg_reviews_host.values, palette='magma')

plt.title('Average Number of Reviews vs Host Name (Top 20 Hosts)', fontsize=14)
plt.xlabel('Host Name')
plt.ylabel('Average Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3761980356.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_reviews_host.index, y=avg_reviews_host.values, palette='magma')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this bar chart because it's the most straightforward way to compare average reviews across different hosts. Since we’re dealing with individual names and numeric values, a bar chart makes it easy to spot who’s getting the most engagement at a glance. It also helps to visually rank the hosts, which wouldn't be as effective with something like a line or pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The first thing that stands out is that Dona has a significantly higher average number of reviews than the rest, crossing the 600 mark.
#
# Hosts like Asa, Dennis & Naoko, and Miss Dy also have strong engagement, hovering around the 450-500 range.
#
# The review averages gradually decline from left to right, but even those near the bottom still maintain decent engagement (around 300), which suggests consistent booking and guest interaction among the top 20.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are useful. Knowing which hosts attract the most reviews could help the platform highlight what's working—maybe it's better communication, pricing, or listing quality. Airbnb or similar platforms can learn from the top hosts and use that to support or coach newer or struggling ones.
#
# However, if only a few hosts are consistently dominating the reviews, it could mean smaller or newer hosts aren't getting enough visibility. That could lead to frustration or drop-offs in host retention. So while the top-performers bring value, the platform might want to make sure it's not too skewed in their favor.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Group by host name and calculate average price
avg_price_by_host = feature_df.groupby('host_name')['price'].mean().sort_values(ascending=False)

# Optional: Display top 10 hosts with highest average price
top_hosts = avg_price_by_host.head(10)

# Plotting
plt.figure(figsize=(12, 6))
top_hosts.plot(kind='bar', color='teal')
plt.title('Top 10 Hosts by Average Price')
plt.xlabel('Host Name')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this bar chart because it provides a clear view of how average pricing varies among the top hosts. It's an effective way to compare host-level pricing without overwhelming detail, especially since prices are numeric and hosts are categorical. This format makes it easy to spot pricing leaders and outliers at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Olson and Rum charge significantly higher prices compared to others, averaging around 10,000 and 8,500 $ respectively.
#
# There's a noticeable price drop from the top 2 hosts to Jay And Liz, who average $6,000.
#
# The rest of the hosts in the top 10 fall within a mid-range bracket of $ 3,000 to 5,000.
#
# The names Sarah-2 and Sarah-B appearing separately could indicate different listings or profiles for the same person, worth exploring for duplication or branding.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights are useful:
#
# Positive impact:
# The platform can use this data to identify premium listings and study what justifies their higher price points—possibly location, amenities, or customer experience. Learning from high earners can help newer hosts improve their offerings or pricing strategy.
#
# Potential concern:
# There's a large pricing gap between top earners and others. If those high prices aren't backed by strong guest reviews or occupancy rates, it could signal overpricing and affect customer satisfaction.
# Also, if multiple profiles from the same host exist (e.g., Sarah-2 vs Sarah-B), it might cause confusion and dilute brand value or affect trust.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
feature_df.describe()

# using corr() function to check the correlation between numeric columns.
corr_df = feature_df[['price', 'minimum_nights', 'number_of_reviews',
             'reviews_per_month', 'listings', 'availability_365']].corr()

# Visualizing correlation using seaborn heatmap, using annotations.
sns.heatmap(corr_df, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is ideal for visualizing the relationships between numerical variables. It uses color intensity to show how strongly features are related to each other—darker shades for strong correlations and lighter ones for weaker or no correlation. This gives a quick, clear overview of how different variables interact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals which variables have strong positive or negative relationships.
#
# It shows which features are closely connected, helping us understand the structure of our data.
#
# We can also spot potential multicollinearity—when two or more variables are highly correlated, which is important if we plan to use regression or predictive models.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Let's create a pairplot to know the relationship between our few variables.

pair_df = feature_df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'listings', 'availability_365', 'price_range']]
sns.pairplot(pair_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we can easily see the distribution of our numerical variables, it will also give us an overview of our dataset and the relationships between our variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Yes, we can see that the utmost majority of our complete data set is within the price range of 0-2500.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# After a thorough analysis of the dataset, several actionable strategies emerge:
#
# Pricing Strategy:
# The majority of bookings fall within the $0-300 range. Aligning most listings to this range can increase competitiveness and attract more customers.
#
# Room Type Focus:
# Entire home/apartment is the most preferred room type, highlighting guests priority for privacy and safety. Introducing stronger privacy and security policies can boost trust and brand reputation.
#
# Location-Based Targeting:
# The Financial District in the Manhattan group sees the highest demand and reviews. Tailoring recommendations and marketing for this area based on pricing and amenities can maximize returns.
#
# Replicating Success in Other Areas:
# Insights from the most-reviewed areas can be applied to underperforming neighborhoods — improving amenities, pricing, and service in those locations could help spread business growth evenly.
#
# Customer Segmentation Opportunity:
# Adding an “occupation” field to future datasets would allow segmentation by profession. This can reveal accommodation preferences for different occupational groups, enabling personalized marketing and property offerings.
#
# Market Positioning:
# The data provides a clear picture of the budget range and customer group contributing the most to business. Strengthening services for this group while designing offers for untapped segments can boost both retention and expansion.
#
# Overall, focusing on competitive pricing, customer privacy, and replicating success across locations — while improving data collection for deeper segmentation — can directly support the business objective of increasing bookings and revenue.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The conclusion of this EDA project is simple and clear — we have enough data to see what our customers like and what they demand. It’s evident that around 90% of our business is concentrated on one side, whether in terms of area preference or pricing. We can use this insight to understand what works best for our customers and apply those strategies to other areas as well.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
